# %% [markdown]
# # Processing ssm info for ete visualization in Python
#
# Note: markdown syntax can be reviewed here: https://daringfireball.net/projects/markdown/syntax#philosophy
#
# - varGroups.rds files need to be converted into python-readable forms first
# - varGroups and snv.out need to be matched
# - Need to intersect snv information with GOI (pull out cancer drivers)
# - unzip all mut assignments
# - DFS tree in order to figure out ancestry and assign mutations
# - [strike] Generate heatmap face attributes for each node in phylo tree
# - add text annotation of protein symbol + aa change for nodes where they appear
# - Visualize in ETE

# %% [markdown]
# ***
# #### Grab tsv files containing SNV information
# !! NOTE: will also need to grab mutassignments at some point. Don't need snv.out though, since we already know the ssm ids

# %%
import glob

# %%
infiles = glob.glob('/Volumes/yjiao-1/phylowgs2/inputs/*.tsv')

# %% [markdown]
# #### Using Pandas to read the cnv file into a pandas DataFrame

# %%
from pandas import read_csv
i = 4
snvs = read_csv(infiles[i], delimiter='\t')

# %%
infiles
# Out:
# ['/Volumes/yjiao-1/phylowgs2/inputs/208T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/253T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/51T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/272T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/39T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/42T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/122T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/98T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/25T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/155T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/PD004T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/148T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/62T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/131T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/99T_varGroups.tsv',
#  '/Volumes/yjiao-1/phylowgs2/inputs/T33T_varGroups.tsv']

# %% [markdown]
# - - -
# #### Some interesting methods for inspecting pandas dataframes

# %%
#snvs.info()
#snvs.dtypes
#snvs.describe()
#snvs.head()

# slicing
# snvs[['id', 'Hugo_Symbol']].head()

# logical indexing
# snvs[snvs.Hugo_Symbol=='B2M']

# set index
# Note THIS IS NOT IN PLACE BY DEFAULT!
snvs.set_index('id', inplace=True)
snvs.head()

# indexing should now be done w/ snvs.ix['s0']

# reset index back to default
#snvs.reset_index(inplace=True)
# Out:
#    Hugo_Symbol  Chromosome  Start_position  End_position  \
# id
# s0      ZRANB1          10       126631628     126631629
# s1      PWWP2B          10       134218579     134218579
# s2      PWWP2B          10       134218579     134218579
# s3       TTC40          10       134738230     134738230
# s4       TTC40          10       134738230     134738230
#
#    Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# id
# s0           In_Frame_Ins          INS                -                 -
# s1      Missense_Mutation          SNP                C                 C
# s2      Missense_Mutation          SNP                C                 C
# s3      Missense_Mutation          SNP                C                 C
# s4      Missense_Mutation          SNP                C                 C
#
#    Tumor_Seq_Allele2  Match_Norm_Seq_Allele1             ...               \
# id                                                       ...
# s0            GGACTG                     NaN             ...
# s1                 T                     NaN             ...
# s2                 T                     NaN             ...
# s3                 T                     NaN             ...
# s4                 T                     NaN             ...
#
#     q_hat HS_q_hat_1 HS_q_hat_2      samp order  \
# id
# s0      2          1          1  SM-61EWU     1
# s1      2          1          1  SM-61EWU     1
# s2      3          1          2  SM-61EWU     1
# s3      2          1          1  SM-61EWU     1
# s4      3          1          2  SM-61EWU     1
#
#                                           ID cnv_field    gene  \
# id
# s0  g.chr10:126631628_126631629insGGACTG_1_1    s0,1,1  ZRANB1
# s1                  g.chr10:134218579C>T_1_1    s1,1,1  PWWP2B
# s2                  g.chr10:134218579C>T_1_2    s2,1,2  PWWP2B
# s3                  g.chr10:134738230C>T_1_1    s3,1,1   TTC40
# s4                  g.chr10:134738230C>T_1_2    s4,1,2   TTC40
#
#                             a                            d
# id
# s0  264,152,92,33,207,194,274    264,152,92,58,207,194,274
# s1     44,35,92,148,67,40,274      89,51,92,295,117,81,274
# s2  264,152,86,377,207,194,77  264,152,257,377,207,194,230
# s3     37,26,92,78,34,194,274      59,48,92,156,59,194,274
# s4  264,152,21,377,207,194,65   264,152,64,377,207,194,140
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Import GOI information

# %%
goi = read_csv('/Volumes/yjiao-1/phylowgs2/output/goi_from_moshe_20160222.csv', delimiter=',')
goi.head()
# Out:
#   Gene Name   Popular Name                                           Function  \
# 0    PSMB8            LMP7  Catalytic unit of the immunoproteosome, suited...
# 1     PSMB9           LMP2  Catalytic unit of the immunoproteosome, suited...
# 2    PSMB10  LMP10 (MECL1)  Catalytic unit of the immunoproteosome, suited...
# 3     ERAP1          ERAP1  involved in trimming HLA class I-binding precu...
# 4     ERAP2          ERAP2         Acts as a monomer or hetrodimer with ERAP1
#
#    Location                                           Category Pathway  Chr  \
# 0   6p21.32  Genes involved in the processing of class I HL...     HLA  NaN
# 1  6p21.32   Genes involved in the processing of class I HL...     HLA  NaN
# 2   16q22.1  Genes involved in the processing of class I HL...     HLA  NaN
# 3      5q15  Peptide triming for generation of most HLA-I b...     HLA  NaN
# 4      5q15  Peptide triming for generation of most HLA-I b...     HLA  NaN
#
#    Pos
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
goi.Pathway = map(str.strip,goi.Pathway)
goi['Gene Name'] = map(str.strip,goi['Gene Name'])
drivers = goi[goi.Pathway=='Driver genes in melanoma']
drivers = set(drivers['Gene Name'])

# %% [markdown]
# ***
# ## Intersect varGroup and GOI
#
# Note that some of these might be the same genomic change, but with different copy numbers. We want to merge them under the assumption that each genomic change only happened once.

# %%
goiflag = [True if a in drivers else False for a in list(snvs.Hugo_Symbol) ]
dsnvs = snvs[goiflag]

# %%
import json
# temporary for now, later we'll know which one we actually want
patient = '39T'
tree = 2256
path = '/Volumes/yjiao-1/phylowgs2/output/witness/data/' + patient + '/mutass/' + str(tree) + '.json'
with open(path) as f:
    ms = f.readline()
ms = json.loads(ms)

# %%
for population in ms['mut_assignments']:
    for ssm in dsnvs.index:
        if ssm in ms['mut_assignments'][population]['ssms']:
            info = list(dsnvs.loc[ssm][['Hugo_Symbol', 'Protein_Change', 'HS_q_hat_1', 'HS_q_hat_2']])
            mutstring = info[0] + ' ' + info[1].replace('p.','') + ' copies: ' + ','.join(map(str,info[2:]))
            print mutstring
# Out:
# BRAF V600E copies: 1,2
# GNA11 R183C copies: 2,2
# BRAF V600E copies: 2,2

# %%
dsnvs.keys()
# Out:
# Index([u'Hugo_Symbol', u'Chromosome', u'Start_position', u'End_position',
#        u'Variant_Classification', u'Variant_Type', u'Reference_Allele',
#        u'Tumor_Seq_Allele1', u'Tumor_Seq_Allele2', u'Match_Norm_Seq_Allele1',
#        u'Match_Norm_Seq_Allele2', u'Genome_Change', u'Codon_Change',
#        u'ref_context', u'Annotation_Transcript', u'Protein_Change',
#        u'Description', u'alt', u'ref', u'ccf_hat', u'ccf_CI95_low',
#        u'ccf_CI95_high', u'detection_power', u'purity',
#        u'detection_power_for_single_read', u'q_hat', u'HS_q_hat_1',
#        u'HS_q_hat_2', u'samp', u'order', u'ID', u'cnv_field', u'gene', u'a',
#        u'd'],
#       dtype='object')

# %%
with open('/Volumes/yjiao-1/phylowgs2/inputs/39T.cnv') as f:
    test = read_csv(f, delimiter='\t')
for entry in test.ssms:
    try:
        ssms = entry.split(';')
        ssms = [s.split(',')[0] for s in ssms]
        if 's397' in ssms or 's398' in ssms:
            print test[test.ssms==entry]
    except:
        pass
# Out:
#       cnv                                                 a  \
# 732  c732  669124,669124,669124,334562,669124,669124,669124
#
#                                                     d  \
# 732  669124,669124,669124,669124,669124,669124,669124
#
#                            ssms
# 732  s386,1,2;s393,1,2;s397,1,2
#       cnv                                                  a  \
# 733  c733  8980322,3607298,14677362,17960644,14677362,122...
#
#                                                      d  \
# 733  17960644,7214596,29354724,17960644,29354724,24...
#
#                                                   ssms
# 733  s387,2,2;s388,2,2;s391,2,2;s392,2,2;s394,2,2;s...

# %%
dsnvs.keys()
# Out:
# Index([u'Hugo_Symbol', u'Chromosome', u'Start_position', u'End_position',
#        u'Variant_Classification', u'Variant_Type', u'Reference_Allele',
#        u'Tumor_Seq_Allele1', u'Tumor_Seq_Allele2', u'Match_Norm_Seq_Allele1',
#        u'Match_Norm_Seq_Allele2', u'Genome_Change', u'Codon_Change',
#        u'ref_context', u'Annotation_Transcript', u'Protein_Change',
#        u'Description', u'alt', u'ref', u'ccf_hat', u'ccf_CI95_low',
#        u'ccf_CI95_high', u'detection_power', u'purity',
#        u'detection_power_for_single_read', u'q_hat', u'HS_q_hat_1',
#        u'HS_q_hat_2', u'samp', u'order', u'ID', u'cnv_field', u'gene', u'a',
#        u'd'],
#       dtype='object')

# %%
snvids = map(str, ms['mut_assignments']['1']['ssms'])
snvs.ix[snvids]
# Out:
#      Hugo_Symbol  Chromosome  Start_position  End_position  \
# id
# s206        RGS5           1       163138132     163138132
# s204      TMEM82           1        16073485      16073485
# s202      RSC1A1           1        15988180      15988180
# s201       FCRL6           1       159779992     159779992
# s200        DARC           1       159176200     159176200
# s209      PAPPA2           1       176659467     176659467
# s208         TNR           1       175372542     175372542
# s57       OR51I2          11         5475053       5475053
# s55         LRP4          11        46916350      46916350
# s51         ANO3          11        26655777      26655777
# s59       OR51I2          11         5475364       5475364
# s348     SLC6A18           5         1244870       1244870
# s343       HERC6           4        89311972      89311972
# s340      SLC4A4           4        72352667      72352667
# s119       ARNT2          15        80869228      80869228
# s118      UNC13C          15        54307444      54307444
# s117       PATL2          15        44961745      44961745
# s116         MGA          15        41961210      41961210
# s114      GABRA5          15        27185161      27185161
# s412        VWC2           7        49815396      49815396
# s419       RP1L1           8        10469482      10469482
# s249    C1orf170           1          914329        914329
# s242       PHF13           1         6679869       6679869
# s245    C1orf173           1        75038609      75038609
# s244    C1orf173           1        75038009      75038009
# s9         MYO3A          10        26482179      26482179
# s394       LMOD2           7       123296237     123296237
# s1        PWWP2B          10       134218579     134218579
# s392      CADPS2           7       122047750     122047750
# s398        BRAF           7       140453136     140453136
# ...          ...         ...             ...           ...
# s425       KAT6A           8        41839466      41839466
# s197       PEAR1           1       156884573     156884573
# s196       PEAR1           1       156875138     156875138
# s194     NUP210L           1       154127381     154127381
# s192     NUP210L           1       153998049     153998049
# s191        MCL1           1       150551913     150551913
# s199        CD1E           1       158325195     158325195
# s13       PTCHD3          10        27702393      27702393
# s17     KIAA1462          10        30318371      30318371
# s258      ZNF334          20        45130935      45130935
# s259      CHRNA4          20        61981237      61981237
# s251    KIAA1107           1        92643025      92643025
# s253        RIN2          20        19970942      19970942
# s255        TGM6          20         2411561       2411561
# s257        SGK2          20        42196330      42196330
# s66         FAT3          11        92577341      92577341
# s63       OR52B2          11         6191303       6191303
# s332      GPR125           4        22389807      22389807
# s330        LDB2           4        16504273      16504273
# s85        KRT73          12        53002114      53002114
# s338      LIMCH1           4        41652611      41652611
# s140        MYH4          17        10348150      10348150
# s141     PRPSAP2          17        18833982      18833982
# s142     LGALS9B          17        20361590      20361590
# s144    KRTAP2-4          17        39221718      39221718
# s146         GH2          17        61958432      61958432
# s387       KMT2E           7       104748064     104748064
# s383         DSP           6         7584591       7584591
# s380       KCNQ5           6        73843349      73843349
# s294      KANSL3           2        97276875      97276875
#
#      Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# id
# s206      Missense_Mutation          SNP                C                 C
# s204      Missense_Mutation          SNP                C                 C
# s202      Missense_Mutation          SNP                T                 T
# s201      Missense_Mutation          SNP                C                 C
# s200      Missense_Mutation          SNP                G                 G
# s209      Missense_Mutation          SNP                C                 C
# s208      Missense_Mutation          SNP                G                 G
# s57       Missense_Mutation          SNP                C                 C
# s55       Missense_Mutation          SNP                A                 A
# s51       Missense_Mutation          SNP                G                 G
# s59       Missense_Mutation          SNP                C                 C
# s348      Nonsense_Mutation          SNP                G                 G
# s343      Missense_Mutation          SNP                C                 C
# s340      Missense_Mutation          SNP                A                 A
# s119      Missense_Mutation          SNP                C                 C
# s118      Nonsense_Mutation          SNP                C                 C
# s117      Missense_Mutation          SNP                C                 C
# s116      Missense_Mutation          SNP                A                 A
# s114      Missense_Mutation          SNP                G                 G
# s412      Missense_Mutation          SNP                C                 C
# s419      Missense_Mutation          SNP                G                 G
# s249      Missense_Mutation          SNP                C                 C
# s242      Missense_Mutation          SNP                C                 C
# s245      Missense_Mutation          SNP                C                 C
# s244      Missense_Mutation          SNP                C                 C
# s9        Missense_Mutation          SNP                G                 G
# s394      Missense_Mutation          SNP                G                 G
# s1        Missense_Mutation          SNP                C                 C
# s392            Splice_Site          SNP                C                 C
# s398      Missense_Mutation          SNP                A                 A
# ...                     ...          ...              ...               ...
# s425      Missense_Mutation          SNP                G                 G
# s197      Nonsense_Mutation          SNP                C                 C
# s196      Missense_Mutation          SNP                C                 C
# s194      Missense_Mutation          SNP                G                 G
# s192      Missense_Mutation          SNP                C                 C
# s191      Missense_Mutation          SNP                C                 C
# s199      Missense_Mutation          SNP                C                 C
# s13       Missense_Mutation          SNP                C                 C
# s17       Missense_Mutation          SNP                G                 G
# s258      Missense_Mutation          SNP                G                 G
# s259      Missense_Mutation          SNP                G                 G
# s251      Missense_Mutation          SNP                G                 G
# s253      Missense_Mutation          SNP                G                 G
# s255      Missense_Mutation          SNP                G                 G
# s257      Missense_Mutation          SNP                C                 C
# s66       Missense_Mutation          SNP                G                 G
# s63       Missense_Mutation          SNP                G                 G
# s332      Nonsense_Mutation          SNP                G                 G
# s330      Missense_Mutation          SNP                G                 G
# s85       Missense_Mutation          SNP                C                 C
# s338      Missense_Mutation          SNP                C                 C
# s140      Missense_Mutation          SNP                G                 G
# s141      Missense_Mutation          SNP                C                 C
# s142      Missense_Mutation          SNP                C                 C
# s144      Missense_Mutation          SNP                G                 G
# s146      Missense_Mutation          SNP                G                 G
# s387      Missense_Mutation          SNP                G                 G
# s383      Missense_Mutation          SNP                C                 C
# s380      Missense_Mutation          SNP                A                 A
# s294            Splice_Site          SNP                C                 C
#
#      Tumor_Seq_Allele2  Match_Norm_Seq_Allele1              ...                \
# id                                                          ...
# s206                 T                     NaN              ...
# s204                 T                     NaN              ...
# s202                 C                     NaN              ...
# s201                 T                     NaN              ...
# s200                 A                     NaN              ...
# s209                 T                     NaN              ...
# s208                 A                     NaN              ...
# s57                  T                     NaN              ...
# s55                  G                     NaN              ...
# s51                  A                     NaN              ...
# s59                  T                     NaN              ...
# s348                 A                     NaN              ...
# s343                 T                     NaN              ...
# s340                 G                     NaN              ...
# s119                 T                     NaN              ...
# s118                 T                     NaN              ...
# s117                 T                     NaN              ...
# s116                 T                     NaN              ...
# s114                 A                     NaN              ...
# s412                 T                     NaN              ...
# s419                 A                     NaN              ...
# s249                 T                     NaN              ...
# s242                 T                     NaN              ...
# s245                 G                     NaN              ...
# s244                 T                     NaN              ...
# s9                   A                     NaN              ...
# s394                 A                     NaN              ...
# s1                   T                     NaN              ...
# s392                 T                     NaN              ...
# s398                 T                     NaN              ...
# ...                ...                     ...              ...
# s425                 A                     NaN              ...
# s197                 T                     NaN              ...
# s196                 T                     NaN              ...
# s194                 A                     NaN              ...
# s192                 T                     NaN              ...
# s191                 G                     NaN              ...
# s199                 T                     NaN              ...
# s13                  T                     NaN              ...
# s17                  A                     NaN              ...
# s258                 A                     NaN              ...
# s259                 A                     NaN              ...
# s251                 A                     NaN              ...
# s253                 A                     NaN              ...
# s255                 A                     NaN              ...
# s257                 T                     NaN              ...
# s66                  A                     NaN              ...
# s63                  A                     NaN              ...
# s332                 A                     NaN              ...
# s330                 A                     NaN              ...
# s85                  T                     NaN              ...
# s338                 T                     NaN              ...
# s140                 A                     NaN              ...
# s141                 T                     NaN              ...
# s142                 T                     NaN              ...
# s144                 A                     NaN              ...
# s146                 A                     NaN              ...
# s387                 A                     NaN              ...
# s383                 T                     NaN              ...
# s380                 G                     NaN              ...
# s294                 T                     NaN              ...
#
#       q_hat HS_q_hat_1 HS_q_hat_2      samp order                        ID  \
# id
# s206      4          2          2  SM-61EWU     1   g.chr1:163138132C>T_2_2
# s204      8          2          6  SM-61EWU     1    g.chr1:16073485C>T_2_6
# s202      8          2          6  SM-61EWU     1    g.chr1:15988180T>C_2_6
# s201      4          2          2  SM-61EWU     1   g.chr1:159779992C>T_2_2
# s200      4          2          2  SM-61EWU     1   g.chr1:159176200G>A_2_2
# s209      4          2          2  SM-61EWU     1   g.chr1:176659467C>T_2_2
# s208      4          2          2  SM-61EWU     1   g.chr1:175372542G>A_2_2
# s57       4          2          2  SM-61EWU     1    g.chr11:5475053C>T_2_2
# s55       4          2          2  SM-61EWU     1   g.chr11:46916350A>G_2_2
# s51       4          2          2  SM-61EWU     1   g.chr11:26655777G>A_2_2
# s59       4          2          2  SM-61EWU     1    g.chr11:5475364C>T_2_2
# s348      7          0          7  SM-61EWU     1     g.chr5:1244870G>A_0_7
# s343      4          2          2  SM-61EWU     1    g.chr4:89311972C>T_2_2
# s340      4          2          2  SM-61EWU     1    g.chr4:72352667A>G_2_2
# s119      3          1          2  SM-61EWU     1   g.chr15:80869228C>T_1_2
# s118      3          1          2  SM-61EWU     1   g.chr15:54307444C>T_1_2
# s117      3          1          2  SM-61EWU     1   g.chr15:44961745C>T_1_2
# s116      3          1          2  SM-61EWU     1   g.chr15:41961210A>T_1_2
# s114      3          1          2  SM-61EWU     1   g.chr15:27185161G>A_1_2
# s412      4          2          2  SM-61EWU     1    g.chr7:49815396C>T_2_2
# s419      4          1          3  SM-61EWU     1    g.chr8:10469482G>A_1_3
# s249      8          1          7  SM-61EWU     1      g.chr1:914329C>T_1_7
# s242     10          3          7  SM-61EWU     1     g.chr1:6679869C>T_3_7
# s245      4          2          2  SM-61EWU     1    g.chr1:75038609C>G_2_2
# s244      4          2          2  SM-61EWU     1    g.chr1:75038009C>T_2_2
# s9        3          1          2  SM-61EWU     1   g.chr10:26482179G>A_1_2
# s394      4          2          2  SM-61EWU     1   g.chr7:123296237G>A_2_2
# s1        2          1          1  SM-61EWU     1  g.chr10:134218579C>T_1_1
# s392      4          2          2  SM-61EWU     1   g.chr7:122047750C>T_2_2
# s398      4          2          2  SM-61EWU     1   g.chr7:140453136A>T_2_2
# ...     ...        ...        ...       ...   ...                       ...
# s425      4          1          3  SM-61EWU     1    g.chr8:41839466G>A_1_3
# s197      4          2          2  SM-61EWU     1   g.chr1:156884573C>T_2_2
# s196      4          2          2  SM-61EWU     1   g.chr1:156875138C>T_2_2
# s194      4          2          2  SM-61EWU     1   g.chr1:154127381G>A_2_2
# s192      4          2          2  SM-61EWU     1   g.chr1:153998049C>T_2_2
# s191      4          2          2  SM-61EWU     1   g.chr1:150551913C>G_2_2
# s199      4          2          2  SM-61EWU     1   g.chr1:158325195C>T_2_2
# s13       3          1          2  SM-61EWU     1   g.chr10:27702393C>T_1_2
# s17       3          1          2  SM-61EWU     1   g.chr10:30318371G>A_1_2
# s258      4          2          2  SM-61EWU     1   g.chr20:45130935G>A_2_2
# s259      4          2          2  SM-61EWU     1   g.chr20:61981237G>A_2_2
# s251      4          2          2  SM-61EWU     1    g.chr1:92643025G>A_2_2
# s253      4          2          2  SM-61EWU     1   g.chr20:19970942G>A_2_2
# s255      4          2          2  SM-61EWU     1    g.chr20:2411561G>A_2_2
# s257      4          2          2  SM-61EWU     1   g.chr20:42196330C>T_2_2
# s66       4          2          2  SM-61EWU     1   g.chr11:92577341G>A_2_2
# s63       4          2          2  SM-61EWU     1    g.chr11:6191303G>A_2_2
# s332      4          2          2  SM-61EWU     1    g.chr4:22389807G>A_2_2
# s330      4          2          2  SM-61EWU     1    g.chr4:16504273G>A_2_2
# s85       5          2          3  SM-61EWU     1   g.chr12:53002114C>T_2_3
# s338      4          2          2  SM-61EWU     1    g.chr4:41652611C>T_2_2
# s140      3          1          2  SM-61EWU     1   g.chr17:10348150G>A_1_2
# s141      3          1          2  SM-61EWU     1   g.chr17:18833982C>T_1_2
# s142      3          1          2  SM-61EWU     1   g.chr17:20361590C>T_1_2
# s144      3          1          2  SM-61EWU     1   g.chr17:39221718G>A_1_2
# s146      3          1          2  SM-61EWU     1   g.chr17:61958432G>A_1_2
# s387      4          2          2  SM-61EWU     1   g.chr7:104748064G>A_2_2
# s383      4          2          2  SM-61EWU     1     g.chr6:7584591C>T_2_2
# s380      3          1          2  SM-61EWU     1    g.chr6:73843349A>G_1_2
# s294      3          1          2  SM-61EWU     1    g.chr2:97276875C>T_1_2
#
#      cnv_field      gene                            a  \
# id
# s206  s206,2,2      RGS5         109,52,9,18,51,72,14
# s204  s204,2,6    TMEM82   142,152,148,380,124,94,266
# s202  s202,2,6    RSC1A1         36,152,5,45,29,26,42
# s201  s201,2,2     FCRL6        62,28,10,130,60,32,62
# s200  s200,2,2      DARC         72,24,8,128,36,39,82
# s209  s209,2,2    PAPPA2    155,97,17,348,157,118,217
# s208  s208,2,2       TNR    118,58,36,319,106,104,216
# s57    s57,2,2    OR51I2     126,75,19,166,110,85,274
# s55    s55,2,2      LRP4   280,185,85,808,350,189,274
# s51    s51,2,2      ANO3       124,80,14,46,63,98,274
# s59    s59,2,2    OR51I2    134,89,18,134,114,108,274
# s348  s348,0,7   SLC6A18   272,118,95,1135,104,79,385
# s343  s343,2,2     HERC6     118,95,60,371,144,94,206
# s340  s340,2,2    SLC4A4           103,61,6,10,7,98,7
# s119  s119,1,2     ARNT2         60,33,8,130,43,49,66
# s118  s118,1,2    UNC13C          91,60,8,11,54,80,10
# s117  s117,1,2     PATL2          27,12,92,21,15,27,5
# s116  s116,1,2       MGA         39,25,92,6,23,31,274
# s114  s114,1,2    GABRA5     129,54,7,148,195,125,103
# s412  s412,2,2      VWC2       40,28,55,146,49,34,274
# s419  s419,1,3     RP1L1    184,76,87,377,223,115,261
# s249  s249,1,7  C1orf170   264,152,254,559,124,19,322
# s242  s242,3,7     PHF13    264,152,16,139,207,194,72
# s245  s245,2,2  C1orf173     131,80,17,238,96,107,106
# s244  s244,2,2  C1orf173          88,52,6,72,53,75,12
# s9      s9,1,2     MYO3A     264,74,13,377,80,118,274
# s394  s394,2,2     LMOD2    174,93,14,346,154,104,274
# s1      s1,1,1    PWWP2B       44,35,92,148,67,40,274
# s392  s392,2,2    CADPS2         73,44,6,36,52,60,274
# s398  s398,2,2      BRAF    263,196,18,32,152,206,274
# ...        ...       ...                          ...
# s425  s425,1,3     KAT6A       80,50,92,377,103,56,48
# s197  s197,2,2     PEAR1       74,41,16,222,76,54,136
# s196  s196,2,2     PEAR1        40,24,29,134,53,30,66
# s194  s194,2,2   NUP210L  276,154,141,666,271,212,420
# s192  s192,2,2   NUP210L         78,46,10,63,42,60,11
# s191  s191,2,2      MCL1       78,46,92,225,85,54,104
# s199  s199,2,2      CD1E    254,125,18,208,168,186,82
# s13    s13,1,2    PTCHD3      264,48,55,377,76,70,146
# s17    s17,1,2  KIAA1462       264,49,10,377,56,76,74
# s258  s258,2,2    ZNF334          92,56,6,12,51,80,10
# s259  s259,2,2    CHRNA4         30,19,52,86,32,20,62
# s251  s251,2,2  KIAA1107           72,44,8,12,20,62,6
# s253  s253,2,2      RIN2       44,36,12,116,207,38,80
# s255  s255,2,2      TGM6     144,93,30,412,166,86,205
# s257  s257,2,2      SGK2     136,72,16,337,143,78,202
# s66    s66,2,2      FAT3    142,82,14,268,131,112,274
# s63    s63,2,2    OR52B2   170,104,18,280,149,129,274
# s332  s332,2,2    GPR125      93,46,10,188,106,70,114
# s330  s330,2,2      LDB2      120,45,92,176,58,68,121
# s85    s85,2,3     KRT73     105,68,32,262,102,78,274
# s338  s338,2,2    LIMCH1          64,41,5,97,60,52,55
# s140  s140,1,2      MYH4          71,41,5,49,60,59,16
# s141  s141,1,2   PRPSAP2         60,54,10,80,79,47,35
# s142  s142,1,2   LGALS9B   185,103,92,382,174,135,227
# s144  s144,1,2  KRTAP2-4         32,14,30,68,25,33,40
# s146  s146,1,2       GH2   228,123,29,373,188,186,159
# s387  s387,2,2     KMT2E        92,49,4,118,70,69,274
# s383  s383,2,2       DSP         104,53,8,70,56,83,19
# s380  s380,1,2     KCNQ5       82,43,19,377,74,59,112
# s294  s294,1,2    KANSL3          53,35,6,74,45,46,22
#
#                                   d
# id
# s206       218,104,18,35,102,143,27
# s204  570,152,593,1519,496,374,1065
# s202     145,152,21,180,116,102,169
# s201       124,56,20,261,120,64,125
# s200        145,47,15,257,72,78,163
# s209     310,194,34,696,314,235,434
# s208     235,115,73,638,211,208,433
# s57      251,150,38,332,221,170,274
# s55    559,370,170,1617,700,378,274
# s51       248,161,27,93,126,197,274
# s59      269,178,37,267,229,216,274
# s348   777,512,244,1923,580,357,940
# s343    235,190,121,742,288,189,413
# s340        206,122,11,19,14,196,14
# s119     180,100,25,389,128,147,197
# s118       272,180,24,33,161,236,31
# s117           81,36,92,62,40,82,16
# s116         116,76,92,19,70,92,274
# s114     265,161,22,369,305,209,151
# s412        80,57,110,291,98,69,274
# s419    625,302,249,377,492,435,802
# s249    264,152,466,950,247,153,601
# s242     264,152,53,464,207,194,240
# s245     262,159,34,477,193,214,213
# s244      175,105,11,145,106,150,25
# s9       264,223,38,377,240,353,274
# s394     347,186,28,691,307,208,274
# s1          89,51,92,295,117,81,274
# s392       146,89,12,73,103,119,274
# s398      526,391,35,64,303,411,274
# ...                             ...
# s425     318,200,92,377,341,225,193
# s197      147,82,32,443,152,109,273
# s196        79,47,45,267,106,49,133
# s194   552,308,282,1332,542,425,840
# s192        157,93,21,126,83,121,22
# s191      156,93,92,450,170,109,209
# s199     508,250,37,415,336,371,165
# s13     264,145,165,377,228,210,437
# s17      264,121,29,377,167,193,202
# s258       184,113,12,25,102,161,21
# s259        59,38,103,171,63,40,125
# s251         145,88,15,23,39,123,12
# s253        89,72,24,232,207,75,160
# s255     289,186,59,824,332,172,410
# s257     273,145,33,674,286,155,405
# s66      284,164,28,537,262,225,274
# s63      340,209,35,560,298,258,274
# s332      186,92,21,375,213,141,227
# s330      241,90,92,352,117,136,242
# s85      263,169,80,656,255,195,274
# s338      127,82,10,194,119,104,110
# s140      214,124,14,146,179,177,48
# s141     179,162,28,239,238,140,104
# s142    556,309,92,1147,523,406,682
# s144         95,41,91,203,76,98,121
# s146    685,370,87,1120,565,557,476
# s387       185,98,9,236,141,138,274
# s383      208,106,17,140,112,166,38
# s380     204,128,33,377,221,178,336
# s294      160,106,18,221,135,137,66
#
# [142 rows x 35 columns]

# %%
# Out:
#      Hugo_Symbol Protein_Change
# id
# s163       GNA11        p.R183C
# s397        BRAF        p.V600E
# s398        BRAF        p.V600E
